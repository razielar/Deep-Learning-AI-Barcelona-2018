# %% [markdown]
# # Simple RNN with Keras
# ## April 5th 2019
# ### Build and train a RNN with Keras; information obtained from: Deep Learning with Keras 2017
# ### Page: 177

# %%
from __future__ import print_function
from keras.layers import Dense, Activation
from keras.layers.recurrent import SimpleRNN
from keras.models import Sequential
# from keras.utils.visualize_util import plot
import numpy as np
import sys, os, re

# %% [markdown]
# ## Preparing data input

# %%
os.chdir('/Users/raziel/Documents/Deep-Learning-AI-Barcelona-2018/Deep_Learning/RNN/SimpleRNN')

fin= 'alice_wonderland.txt'
fin= open(fin, 'rb')

lines=[]
for line in fin:
    line= line.strip().lower()
    line= line.decode("ascii", "ignore")
    if len(line) == 0:
        continue
    lines.append(line)

fin.close()
text=" ".join(lines)
chars= set([i for i in text])
nb_chars= len(chars)

#i=counter, c=char value
char2index= dict((c,i) for i,c in enumerate(chars))
index2char= dict( (i,c) for i,c in enumerate(chars))

SEQLEN= 10
STEP= 1

input_chars= []
label_chars= []

for i in range(0, len(text)- SEQLEN, STEP):
    input_chars.append(text[i:i+ SEQLEN])
    label_chars.append(text[i + SEQLEN])

# %% [markdown]
# ## Vectorize

# %%
X= np.zeros((len(input_chars), SEQLEN, nb_chars), dtype= np.bool)
y= np.zeros((len(input_chars), nb_chars), dtype= np.bool)

for i, input_chars in enumerate(input_chars):
    for j, ch in enumerate(input_chars):
        X[i, j, char2index[ch]] = 1
    y[i, char2index[label_chars[i]]] = 1


print(y.shape, "\n")
print(X.shape)
# Out:
# (158773, 55)
#
# (158773, 10, 55)

# %% [markdown]
# ## Buld our model

# %%
#Hyper-parameters: 
HIDDEN_SIZE= 128 #Experimental validation
BATCH_SIZE= 128
NUM_ITERARIONS= 25
NUM_EPOCHS_PER_ITERATION= 1
NUM_PREDS_PER_EPOCH= 100

#1) Architecture of the model:
model= Sequential()
model.add(SimpleRNN(HIDDEN_SIZE, return_sequences= False, input_shape= (SEQLEN, nb_chars), unroll= True))
model.add(Dense(nb_chars))
model.add(Activation('softmax'))

#2) Compile: Optimizer and loss function: 
model.compile(loss= "categorical_crossentropy", optimizer= "rmsprop")

#3) Fit the model:
#So far the training process was: to train a model for a fixed number of epochs then evaluate the model.
#Here we don't have labeled data 
for iterator in range(NUM_ITERARIONS):
    print('=' * 50) #"rep in R"
    print("Iterator #: %d" %(iterator))
    model.fit(X, y, batch_size= BATCH_SIZE, epochs= NUM_EPOCHS_PER_ITERATION)

    test_idx= np.random.randint(len(input_chars))
    test_chars= input_chars[test_idx]
    print("Generation from seed: %s" % (test_chars))
    print(test_chars, end="")

    for i in range(NUM_PREDS_PER_EPOCH):
        Xtest= np.zeros((1, SEQLEN, nb_chars))
        for i, ch in enumerate(test_chars):
            Xtest[0, i, char2index[ch]] = 1
        #4) Model Predict: 
        pred= model.predict(Xtest, verbose= 0)[0]
        ypred= index2char[np.argmax(pred)]
        print(ypred, end="")
        # move forward with test_chars + ypred
        test_chars= test_chars[1:] + ypred
print()
# Out:
# ==================================================
# Iterator #: 0
# Epoch 1/1
# 158773/158773 [==============================] - 10s 65us/step - loss: 2.3425
# Generation from seed: w
# w                                                                                                    ==================================================
# Iterator #: 1
# Epoch 1/1
# 158773/158773 [==============================] - 10s 63us/step - loss: 2.0497
# Generation from seed: b
# b                                                                                                    ==================================================
# Iterator #: 2
# Epoch 1/1
# 158773/158773 [==============================] - 10s 64us/step - loss: 1.9473
# Generation from seed: e
# e                                                                                                    ==================================================
# Iterator #: 3
# Epoch 1/1
# 158773/158773 [==============================] - 12s 79us/step - loss: 1.8665
# Generation from seed: e
# eiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii==================================================
# Iterator #: 4
# Epoch 1/1
# 158773/158773 [==============================] - 11s 68us/step - loss: 1.8010
# Generation from seed: b
# be                                                                                                   ==================================================
# Iterator #: 5
# Epoch 1/1
# 158773/158773 [==============================] - 11s 66us/step - loss: 1.7474
# Generation from seed: o
# o                                                                                                    ==================================================
# Iterator #: 6
# Epoch 1/1
# 158773/158773 [==============================] - 11s 70us/step - loss: 1.7023
# Generation from seed:
#                                                                                                      ==================================================
# Iterator #: 7
# Epoch 1/1
# 158773/158773 [==============================] - 11s 68us/step - loss: 1.6648
# Generation from seed: o
# o                                                                                                    ==================================================
# Iterator #: 8
# Epoch 1/1
# 158773/158773 [==============================] - 11s 68us/step - loss: 1.6307
# Generation from seed: s
# s                                                                                                    ==================================================
# Iterator #: 9
# Epoch 1/1
# 158773/158773 [==============================] - 11s 70us/step - loss: 1.6031
# Generation from seed: e
# eiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii==================================================
# Iterator #: 10
# Epoch 1/1
# 158773/158773 [==============================] - 11s 69us/step - loss: 1.5772
# Generation from seed: b
# baiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii==================================================
# Iterator #: 11
# Epoch 1/1
# 158773/158773 [==============================] - 11s 71us/step - loss: 1.5555
# Generation from seed: e
# ei                                                                                                   ==================================================
# Iterator #: 12
# Epoch 1/1
# 158773/158773 [==============================] - 11s 68us/step - loss: 1.5356
# Generation from seed: e
# es                                                                                                   ==================================================
# Iterator #: 13
# Epoch 1/1
# 158773/158773 [==============================] - 12s 75us/step - loss: 1.5183
# Generation from seed: k
# k s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. ==================================================
# Iterator #: 14
# Epoch 1/1
# 158773/158773 [==============================] - 11s 68us/step - loss: 1.5019
# Generation from seed: o
# o                                                                                                    ==================================================
# Iterator #: 15
# Epoch 1/1
# 158773/158773 [==============================] - 11s 70us/step - loss: 1.4869
# Generation from seed:
#  y y y y y y y y y y y y y y y y y y y y y y y y y y y y y y y y y y y y y y y y y y y y y y y y y y ==================================================
# Iterator #: 16
# Epoch 1/1
# 158773/158773 [==============================] - 11s 70us/step - loss: 1.4743
# Generation from seed: b
# b.aiou,aiou,aiou,aiou,aiou,aiou,aiou,aiou,aiou,aiou,aiou,aiou,aiou,aiou,aiou,aiou,aiou,aiou,aiou,aiou==================================================
# Iterator #: 17
# Epoch 1/1
# 158773/158773 [==============================] - 11s 70us/step - loss: 1.4622
# Generation from seed: k
# kai,ai,ai,ai,ai,ai,ai,ai,ai,ai,ai,ai,ai,ai,ai,ai,ai,ai,ai,ai,ai,ai,ai,ai,ai,ai,ai,ai,ai,ai,ai,ai,ai,a==================================================
# Iterator #: 18
# Epoch 1/1
# 158773/158773 [==============================] - 11s 70us/step - loss: 1.4513
# Generation from seed: n
# naioioioioioioioioioioioioioioioioioioioioioioioioioioioioioioioioioioioioioioioioioioioioioioioioioi==================================================
# Iterator #: 19
# Epoch 1/1
# 158773/158773 [==============================] - 11s 69us/step - loss: 1.4417
# Generation from seed:
#                                                                                                      ==================================================
# Iterator #: 20
# Epoch 1/1
# 158773/158773 [==============================] - 12s 78us/step - loss: 1.4310
# Generation from seed: k
# ki s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s.==================================================
# Iterator #: 21
# Epoch 1/1
# 158773/158773 [==============================] - 13s 79us/step - loss: 1.4231
# Generation from seed:
#                                                                                                      ==================================================
# Iterator #: 22
# Epoch 1/1
# 158773/158773 [==============================] - 11s 72us/step - loss: 1.4159
# Generation from seed: w
# w s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. s. ==================================================
# Iterator #: 23
# Epoch 1/1
# 158773/158773 [==============================] - 11s 71us/step - loss: 1.4078
# Generation from seed: n
# n                                                                                                    ==================================================
# Iterator #: 24
# Epoch 1/1
# 158773/158773 [==============================] - 12s 73us/step - loss: 1.4009
# Generation from seed: b
# bn o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o
